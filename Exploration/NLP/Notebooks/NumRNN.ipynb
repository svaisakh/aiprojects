# %%
from vaiutils import path_consts
for k, v in path_consts('NumRNN', 'TextGen'):
    exec(k+'=v')

# %%
data = open(DIR_DATA + '/indian_names.txt').read()[:10000]
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print("Data length:", data_size, "\tVocab size:", vocab_size, "Vocab:", ''.join(chars))
char_idx = {c: i for i, c in enumerate(chars)}
idx_char = {i: c for i, c in enumerate(chars)}
# Out:
# Data length: 10000 	Vocab size: 39 Vocab:
# -oij4es/d7hxcgb@ptk q,zn18a2mryfl.w&vu

# %%
hidden_size = 100
seq_length = 10
learning_rate = 1e-1

# %%
Wxh = np.random.randn(hidden_size, vocab_size) * 1e-2
Whh = np.random.randn(hidden_size, hidden_size) * 1e-2
Why = np.random.randn(vocab_size, hidden_size) * 1e-2
bh = np.zeros((hidden_size, 1))
by = np.zeros((vocab_size, 1))

# %%
def lossFunc(inputs, targets, hprev):
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0
    
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size, 1))
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(Wxh.dot(xs[t]) + Whh.dot(hs[t-1]) + bh)
        ys[t] = Why.dot(hs[t]) + by
        ps[t] = np.exp(ys[t]) / np.exp(ys[t]).sum()
        
        loss += -np.log(ps[t][targets[t], 0])
    
    dWxh, dWhh, dWhy, dbh, dby, dhnext = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why), np.zeros_like(bh), np.zeros_like(by), np.zeros_like(hs[0]) 
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1
        dWhy += dy.dot(hs[t].T)
        dby += dy
        dh = Why.T.dot(dy) + dhnext
        dhraw = (1 - hs[t] ** 2) * dh
        dbh += dhraw
        dWxh += dhraw.dot(xs[t].T)
        dWhh += dhraw.dot(hs[t-1].T)
        dhnext = Whh.T.dot(dhraw)
    
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5 , dparam)
        
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs) - 1]

# %%
def sample(h, seed_ix, n):
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    
    ixes = [seed_ix]
    for t in range(n):
        h = np.tanh(Wxh.dot(x) + Whh.dot(h) + bh)
        y = Why.dot(h) + by
        p = np.exp(y) / np.exp(y).sum()
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x[ixes[-1]] = 0
        x[ix] = 1
        ixes.append(ix)
    
    return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy, mbh, mby = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why), np.zeros_like(bh), np.zeros_like(by)
smooth_loss = np.log(vocab_size)*seq_length

while True:
    if p + seq_length + 1 >= len(data) or n == 0:
        hprev = np.zeros((hidden_size, 1))
        p = 0
    
    if seq_length == 0:
        p += seq_length + 1
        continue
        
    inputs = [char_idx[c] for c in data[p : p + seq_length]]
    targets = [char_idx[c] for c in data[p+1 : p + seq_length + 1]]
    
    if n % 1000 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(idx_char[i] for i in sample_ix)
        print('----------\n', txt, '----------\n')
    
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFunc(inputs, targets, hprev)
    
    smooth_loss = smooth_loss * (1 - 1e-3) + loss * 1e-3
    if n % 1000 == 0:
        print("Iteration:", n, "\tLoss:", smooth_loss)
    
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], [dWxh, dWhh, dWhy, dbh, dby], [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam ** 2
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8)
        
    p += seq_length + 1
    n += 1
# Out:
# ----------
#  b7mq,lb4lro,1mr7,h2cq-zpdqikotww dq
# mvzobaz8-,/hw4.m/pngp 8.kqbx/wzsd/aeaiyxid4lsqex78x@zcdaw.@ @mgw@u@/eayyy
# t-q-t
# h. &gieuf2p427.1,w4v2piguo.yxxxdbt&jzbkz1ru,,w.-7tqnwk
# 8,vi/bnxfukn2egcqnxrx@j4t.x.-l ----------
#
# Iteration: 0 	Loss: 36.6356213552
# ----------
#   aziral poorar
# lhuhalulaalohalar cohanf ajal ko
# kalied hah
# anarmiw
# phhwihadir
# yarhaea
# munahut lhweharekwoyhh
# lir n hakandohu @akerohitgh
# aj l
# shuskad
# walabkhashah
# arjush kilal @auran baleumaazal
# rag la ----------
#
# Iteration: 1000 	Loss: 30.9768372441
# ----------
#  masbardiner
# sarita
# sanay
# viner vurudin
# suanshichanaririfijah
# badu chamin
# smander @indev vejay
# sangh
# mohu
# doher umanden
# shakh
# sor
# kumaet
# avarba andeel
# aakayar
# aikurasoy
# sitsa
# kanhad
# shigesh kumavup
# rar
#  ----------
#
# Iteration: 2000 	Loss: 26.3333260634
# ----------
#
# eeneep
# pajdeelaben drarph chanmar
# dea
# vitir mavavek
# agingu kumar
# bazder
# pingh kupish
# aregh
# rarprak epviv
# nkhit
# ciipra
# jingudeepay pumau
# bafpveshaddmal @ kumar
# preepr
# moer
# sindeumar
# rinkrhirirdde
# hahdi ----------
#
# Iteration: 3000 	Loss: 23.7876051742
# ----------
#  hushakq kl
# amr
# vesamaree
# sumar
# eshsharirash prul
# mithaay
# var
# sungeyansak
# nlrmil male lal chashy
# sirun shi juma
# mulr
# psh
# ravit kulul
# dabri
# mablaen
# pr ga nfei nd. kumam
# visarykumam
# kumar wam
# pahamr
# shhes ----------
#
# Iteration: 4000 	Loss: 22.4142445741
# ----------
#  uajkumar
# rashar
# shikamabharul
# s/den
# hahttaran sanjan
# larshi
# manjayah
# rahin
# bajikaj
# narh
# shahhd
# agar
# rahit
# saiyay
# dikhan
# ragunav
# sinu
# hand
# rald
# raghish kharo
# nishuman
# mingh
# taghder sajh
# shthdr
# porumaral ----------
#
# Iteration: 5000 	Loss: 21.6267048136
# ----------
#  inamal
# irar
# namay shari
# deenyader ramud
# amdwa
# prwan
# tooewan shand
# payask kumana
# jahash
# bendev aomender
# mutithakavprel chang
# mam sanl
# dart
# karan
# ring
# ramesin
# apjim
# koray
# singen
# mobishariy
# radit
# mahfay
# n ----------
#
# Iteration: 6000 	Loss: 21.0420886285
# ----------
#
# baita
# sarsh
# babub
# rasalabdev
# mabhar
# risab
# s dar chindirabd konishrukar
# azdish
# abhul
# rajwa jan
# rabl suchas sishishibing
# daban
# rander
# craj
# abind
# rabar
# birti
# raha
# sad pek mungh
# argav bhat
# nyisar kuvirder ----------
#
# Iteration: 7000 	Loss: 20.6763376507
# ----------
#  eendir
# mari
# ram jitvhad
# shuntar hura
# surir
# r
# mar
# bhesh rav
# vibhu
# payhad
# jai
# tiner
# aartw
# ramjudeep
# singh kumir
# rcpar
# rirish
# aarmar chek
# rmar
# airabsan
# raji
# ardek
# l
# rainghausharin avin mfal
# argad
# mun
# sapp ----------
#
# Iteration: 8000 	Loss: 20.3401429032
# ----------
#
# jafpak mohit khararaish
# sajm main pakarvekamat mavyik
# jeendek
# rajat
# mahbh
# rulag
# mikesh
# dijat linkaowend kumar
# jhakes2fkerraj
# vesha kumar
# n suchiraneet kumar
# dinamasa
# kenderwar
# mati@ chal humivol dinsu ----------
#
# Iteration: 9000 	Loss: 20.0193485568
# ----------
#  dikesh
# sarmar sing
# deenamanl abaraj
# ukiaf
# ndesh
# tor
# vaboant
# rakit
# hurt kumar
# rashav
# aviiam tammeema
# sar
# aqash
# rulijan
# vi
# ama.
# oipen armeep
# paumar singh shal
# viman shabhath
# vinderv shakunash kumar
# mahd. ----------
#
# Iteration: 10000 	Loss: 19.7566776192
# ----------
#  n
# mal charka
# rahumar
# nomikd. kaykumar
# vikak singh
# achsajas pawrayndav
# oshi
# chank
# gojera
# ditaprajehal
# pangu andeep kumar
# raamar
# rajmajaddushajay tud avhat
# vuev
# dee@ pyanja @ satdi hoochal
# danjar
# rajogi
#  ----------
#
# Iteration: 11000 	Loss: 19.4262131701
# ----------
#  naindera
# dagal viwas
# pab@ sunaunaja
# badundahbaab
# nalin
# samam sinu
# dulesh
# arman
# janja
# sainder
# abiwandumargu mi
# vev ankumarkim shahal
# vish
# surim
# vino mamun
# vitan
# vishukari kumar
# ranl
# bamkaarhadiviravin
# v ----------
#
# Iteration: 12000 	Loss: 19.2690079497
# ----------
#  ishu
# ladesh
# daren
# vitaz kumar
# didev
# hiioh
# hamit
# saruh huddirusan
# deeppek badu kumar
# deeram
# rohit
# binch
# sakar kumar
# hivesh
# skrar
# pisha
# charsh
# aham
# dufhagwar
# bikal
# singeer
# ruman
# visim singh
# shi s/sad kum ----------
#
# Iteration: 13000 	Loss: 18.9977268058
# ----------
#  agq
# amark
# sarketin kashi saamith kumar
# jadumal kumar @ mishu
# trash
# farman
# mbnesh
# mavpram kumar
# kushaq rendeshy kulabhora
# jeepa
# sollitraveel
# alhar
# kamal chara
# ndem haingh
# bumit
# shgh
# viek
# rint rujan
# vabi ----------
#
# Iteration: 14000 	Loss: 18.8090276288
# ----------
#   keshanighgan
# johd kumar
# molu
# akushy
# para@ abram deran
# raj misen
# bekya
# hafutatash kumar @ pang
# ranushadha
# singhakuchaikashuh
# rajee mal sangh
# sasbireender hanj
# assur
# rajshak saday
# narmah namash kumar sh ----------
#
# Iteration: 15000 	Loss: 18.6287246995
# ----------
#  mudtu
# mrom jar
# chureen harbon
# raju
# man shnder
# misepal kateep
# majagul
# perdender
# pangh
# kaneep
# pam singh
# amoh
# sahar
# vahit
# drakumar
# sait p yonu
# jar adav rahum kupta
# sanas langunahhu kumar
# rghun
# gadn
# pasend ----------
#
# Iteration: 16000 	Loss: 18.4255997626
# ----------
#  huma
# vamejp
# soja
# subil
# nbeepal
# laja
# arbibaalal
# sijmob
# dipdav
# tiran sheder alees sona
# vivek gaush charaj khip
# k
# shit garit
# taubh
# shitin
# rahlan
# aon kamarakhoon @ kumar
# rammishawas kumar sikawa4 raju shes ----------
#
# Iteration: 17000 	Loss: 18.3838214275
# ----------
#  achainav
# lajeep
# vivan rangh
# aman abhan
# panju
# kikgi khar
# sandendra
# karoh
# sarsili
# jhad tihaikula
# ravin
# vivek
# chawar
# swander
# heran
# rasa
# viper finit
# an
# ravit @ cingh
# araj
# gankaserkahiu
# san1u
# aru
# drwal
# praj ----------
#
# Iteration: 18000 	Loss: 18.263540178
# ----------
#  der nit
# amesh
# bokam alu
# lam kuma
# sameep kamir hadnd  sind. bithushrkab
# riji
# nmumaraj
# umiran
# sorshar
# jakya
# sh kumar masil lam shit
# sur
# narjekh
# sohawh shad
# khah kandeer
# razjasi
# abad kusar shanjal
# deedesh ----------
#
# Iteration: 19000 	Loss: 18.0684811996
# ----------
#  hanesh
# ma chan
# shubharaj
# sahin
# pmupar
# vmender
# mdesh
# visharbhukar
# jhalt
# rareep
# yadeer
# raman
# raken sity
# amal
# mit
# kadan
# manil
# inku kushy
# singh
# shap
# pasesh sla risin
# motder paukul @ kara
# sunal mat @ kha pe ----------
#
# Iteration: 20000 	Loss: 17.9107843073
# ----------
#  raj
# saj pashv
# agbur pr/oy kumar kumar
# aheiv kumar
# monil
# deepaswal
# vambin
# pafat
# sanih
# raj san
# rohin
# dhanjeet singe rahsin kumar
# pasam singh
# mahpev shagt kumar
# suphu saroi gadesh sighinajakar deresharma
#  ----------
#
# Iteration: 21000 	Loss: 17.7368633085
# ----------
#
# sharma
# rgoon @ sish ghavi
# sul niv
# viteli
# chuiwal dee
# sabal
# sughah
# nashu
# arahaom dhank
# sanishu
# amash taash dubhujar
# sahul
# moiyoyaman
# avifingol kumar
# amit mumar aishyamity
# awan
# vipar
# rajay
# doudnalavi
# pi ----------
#
# Iteration: 22000 	Loss: 17.6381780919
# ----------
#
#  rgkh kverash
# kagsogu
# razrj kumi harmi shayaak
# miiy
# abhishu
# murimindramad
# paritadiwand
# vijeep kamar khing@ saday khikhindeep kumar
# rajandeepak
# nder
# yasal khit pik kumar
# parsh
# bingh
# kasdaj kumar shak s ----------
#
# Iteration: 23000 	Loss: 17.4705203932
# ----------
#  tender
# kakil
# sokam abhimyarman shaklaq
# ngush sanu
# limev kumar
# jitender
# chenderkumar
# pram kuma
# ondu kular
# jkhan prandeer singh
# modi malu
# hyaban
# amishunamj
# surgh ajalay
# guman
# ajerma
# bluparawari
# vanj yu
# r ----------
#
# Iteration: 24000 	Loss: 17.341761567
# ----------
#  hajeapramit malal haraj
# akaj
# sumar
# seila
# rajeer
# adal
# madesh
# araj
# sashir
# rijeeer khan
# satshegh
# rahsashimansu kumar
# raj kumar
# aaju
# ram kasash
# ramu
# psipdaji
# deemajar jush sani
# dinishapandesh
# sannay
# vehain ----------
#
# Iteration: 25000 	Loss: 17.2435373946
# ----------
#  yaf mand
# yumender
# rughwar vbar
# mamiprainder
# salsh
# nanol
# kadan segh
# curender
# lahul
# ponesh chand
# rvander
# dindey
# rikumar
# rahek1m hanwar
# yusiny
# dervender
# rohit
# gattob @ kumar
# chmohsh
# araj
# sagh
# pawoor
# pumay ----------
#
# Iteration: 26000 	Loss: 17.0838612853
# ----------
#  ukham
# pekhan
# ravees
# kobna
# rohdam
# pabhat
# shyan
# veerapay pashi bh
# jahaom
# karju
# aam
# divekh sank kam kura
# sahubhasmendu dtin
# rabeg bhaddab
# narshul a dhak
# sarbod
# bhitak
# babdul
# babar charmer
# vini
# sunra
# baksh ----------
#
# Iteration: 27000 	Loss: 17.0723551337
# ----------
#
# ra kumar tagy divir singh
# aminderdeepre
# maru
# indh kingh
# swann
# karerar
# warin
# rajit
# bhand
# bhatin
# muner
# durer itort
# shayar
# anju
# surdettaurarkush
# man
# arukl
# auran
# vapul singh
# nitantar
# rajayan
# razinderam
# nd ----------
#
# Iteration: 28000 	Loss: 17.0296915692
# ----------
#   kumar yadu
# hoitaserin
# ruma
# singh
# makish kalimshin
# ram manash sanu
# mohan
# shisender
# bwandera
# amar @ chand ar @ abesh kaman
# abkhar yoxapan
# rame d raj
# nahuk singh
# sakh
# bhasay
# sagh
# imdder
# kumar
# aldil
# rajh
#  ----------
#
# Iteration: 29000 	Loss: 16.877842417
# ----------
#  rar
# azaj
# salel katsl
# rivin
# bautt swarivishr
# marma sharsh sichender
# rimesh
# rajasha singh
# mohoh @/o
# pbhan
# galu
# daisuva
# sulel ramal shad @ kumar
# charulandhant @ rashenarj mit
# sudau
# andde
# gisanana
# ravin
# mu ----------
#
# Iteration: 30000 	Loss: 16.6933622156
# ----------
#  eesi
# birs
# shilan
# marijaasmunish sab. agprijaipaakan sanj
# yalwar
# parmid
# holi all
# aasaya sirfart
# amal @
# vishani
# s/j washasazantya
# gudan mali
# tiul chahab
# shh
# kaharaman ralu rijan
# pakad kafyad chour khond  ----------
#
# Iteration: 31000 	Loss: 16.5441961467
# ----------
#  dso
# shya
# harmendi @ valn
# rahi jasha
# ahit kumar akkam rajabad
# vija
# sanci sayal praj mandkumaradu
# haninan
# abiyulalay
# bharvender
# kosh kadya
# ansushauma
# amaf tulu
# deepalarad jandee
# galy
# dhahavi
# prajan
# masis ----------
#
# Iteration: 32000 	Loss: 16.4511051168
# ----------
#  nad kumar
# vivender
# jiteeb singh kumar
# janesh @ kumar
# peev
# sun
# minga @ nohukdde
# haahari aki
# diveet
# ankal sakit
# bd.itoohchand @ khog yadkin
# kupra
# hankyeed
# ini
# johel
# yujaita kishrin
# manden
# makesh singh
# mo ----------
#
# Iteration: 33000 	Loss: 16.3371952839
# ----------
#  kulasharma @gadka
# rasan dev
# ram gishshandinkaram kumar
# rakh resharinarash kerman shahit
# sunrsh
# shendh
# sabir
# mohy
# amit kumaradarupit
# pra
# moh
# derpa harar
# vilaj
# akal
# porit
# slumarazamheer
# jarmar singh
# haru ----------
#
# Iteration: 34000 	Loss: 16.203048526
# ----------
#  hilas
# sojayajayar
# sona
# saham
# kumar
# pakasn shani
# rohit
# gasas/o mal yagar
# bhutajinaupajaishishanbarkar
# harma
# suppil
# vivel singh peeer
# shankar shgh
# sody
# dindir
# sansiy
# surn
# ravishinanteesh
# akhu
# mduman
# moh ----------
#
# Iteration: 35000 	Loss: 16.0627050039
# ----------
#  agiy
# garav kumar baini
# nd. bhghauparesh rad
# yapeep
# karir
# ram goprk deesh
# maden@ aapayawusharma
# naveep
# mghamjeel
# kuravinderen
# rasyiddender gh gakoddav
# shchat
# munash
# mohan
# panga
# darno
# na
# ranagitrajend
# ra ----------
#
# Iteration: 36000 	Loss: 15.9242050037
# ----------
#   kurar @ vind
# hasto atty
# ibhulashand
# prany
# barhyaso
# uran kumar
# daan
# guppal
# sop
# sawant
# danu
# vikh
# hulul kumar
# @trame& passat
# vahul
# rohi @ baran
# avindmr
# jarpesh ving
# prakadendal
# tabi @ bhrayaqubra@ madwar ----------
#
# Iteration: 37000 	Loss: 15.936014098
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-3f96af5dabf3> in <module>()
#      20         print('----------\n', txt, '----------\n')
#      21
# ---> 22     loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFunc(inputs, targets, hprev)
#      23
#      24     smooth_loss = smooth_loss * (1 - 1e-3) + loss * 1e-3
#
# <ipython-input-11-802056e12117> in lossFunc(inputs, targets, hprev)
#      24         dWxh += dhraw.dot(xs[t].T)
#      25         dWhh += dhraw.dot(hs[t-1].T)
# ---> 26         dhnext = Whh.T.dot(dhraw)
#      27
#      28     for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
#
# KeyboardInterrupt:
